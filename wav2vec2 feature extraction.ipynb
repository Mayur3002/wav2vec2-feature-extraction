# %%
import pandas as pd
import os

# Define the path to your dataset's 'data' directory using a raw string to avoid escape sequence issues.
data_dir = r'C:\Users\Mayur gowda\OneDrive\workspace\atc clone\atcosim_corpus'

# List of Parquet training files
train_files = [
    r'C:\Users\Mayur gowda\OneDrive\workspace\atc clone\atcosim_corpus\data\train-00000-of-00004-c1d7fb31dcbf644a.parquet',
    r'C:\Users\Mayur gowda\OneDrive\workspace\atc clone\atcosim_corpus\data\train-00001-of-00004-f165730df6bf7253.parquet',
    r'C:\Users\Mayur gowda\OneDrive\workspace\atc clone\atcosim_corpus\data\train-00002-of-00004-67e682f17e32b703.parquet',
    r'C:\Users\Mayur gowda\OneDrive\workspace\atc clone\atcosim_corpus\data\train-00003-of-00004-b0b05d4b243c95c6.parquet'
]

# Path to the test file using a raw string
test_file = r'C:\Users\Mayur gowda\OneDrive\workspace\atc clone\atcosim_corpus\data\test-00000-of-00001-01544bdf54b4ccf3.parquet'

# Load and inspect the first train file
for file in train_files:
    file_path = os.path.join(data_dir, file)
    try:
        # Load the Parquet file into a pandas DataFrame
        df = pd.read_parquet(file_path)
        print(f"Loaded {file}: {df.shape} rows and columns")
        print(df.head())  # Display the first few rows to understand the structure
    except Exception as e:
        print(f"Failed to load {file}: {e}")

# Similarly for the test file
test_file_path = os.path.join(data_dir, test_file)
try:
    test_df = pd.read_parquet(test_file_path)
    print(f"Loaded {test_file}: {test_df.shape} rows and columns")
    print(test_df.head())  # Display the first few rows
except Exception as e:
    print(f"Failed to load test file: {e}")
# Out:
# Loaded C:\Users\Mayur gowda\OneDrive\workspace\atc clone\atcosim_corpus\data\train-00000-of-00004-c1d7fb31dcbf644a.parquet: (1910, 6) rows and columns
#                                  id  \
# 0  atcosim_sm1_01_001_000000_000329
# 1  atcosim_sm1_01_002_000000_000466
# 2  atcosim_sm1_01_003_000000_000422
# 3  atcosim_sm1_01_004_000000_000264
# 4  atcosim_sm1_01_005_000000_000391
#
#                                                audio  \
# 0  {'bytes': b'RIFF\x169\x03\x00WAVEfmt \x10\x00\...
# 1  {'bytes': b'RIFF$\x8d\x04\x00WAVEfmt \x10\x00\...
# 2  {'bytes': b'RIFF\x96!\x04\x00WAVEfmt \x10\x00\...
# 3  {'bytes': b'RIFF$\x94\x02\x00WAVEfmt \x10\x00\...
# 4  {'bytes': b'RIFF\xa4\xd1\x03\x00WAVEfmt \x10\x...
#
#                                                 text  segment_start_time  \
# 0       psa eight one zero turn right to trasadingen                 0.0
# 1  lufthansa five three one eight contact zurich ...                 0.0
# ...

# %%
import pandas as pd
import os

# Define the path to your dataset's 'data' directory
data_dir = '/content/atcosim_corpus/data'

# List of Parquet training files
train_files = [
    r'C:\Users\Mayur gowda\OneDrive\workspace\atc clone\atcosim_corpus\data\train-00000-of-00004-c1d7fb31dcbf644a.parquet',
    r'C:\Users\Mayur gowda\OneDrive\workspace\atc clone\atcosim_corpus\data\train-00001-of-00004-f165730df6bf7253.parquet',
    r'C:\Users\Mayur gowda\OneDrive\workspace\atc clone\atcosim_corpus\data\train-00002-of-00004-67e682f17e32b703.parquet',
    r'C:\Users\Mayur gowda\OneDrive\workspace\atc clone\atcosim_corpus\data\train-00003-of-00004-b0b05d4b243c95c6.parquet'
]
test_file = r'C:\Users\Mayur gowda\OneDrive\workspace\atc clone\atcosim_corpus\data\test-00000-of-00001-01544bdf54b4ccf3.parquet'

# Function to load and inspect a Parquet file
def load_and_inspect_parquet(file_path):
    try:
        df = pd.read_parquet(file_path)
        print(f"Loaded {file_path}:")
        print(f"Shape: {df.shape} (rows, columns)")
        print("Columns:", df.columns.tolist())  # Print the list of columns
        print("First few rows:")
        print(df.head())  # Display the first few rows to understand the data
        print("\n")  # Add a newline for better readability
    except Exception as e:
        print(f"Failed to load {file_path}: {e}")

# Load and inspect each training file
for file in train_files:
    file_path = os.path.join(data_dir, file)
    load_and_inspect_parquet(file_path)

# Load and inspect the test file
test_file_path = os.path.join(data_dir, test_file)
load_and_inspect_parquet(test_file_path)
# Out:
# Loaded C:\Users\Mayur gowda\OneDrive\workspace\atc clone\atcosim_corpus\data\train-00000-of-00004-c1d7fb31dcbf644a.parquet:
# Shape: (1910, 6) (rows, columns)
# Columns: ['id', 'audio', 'text', 'segment_start_time', 'segment_end_time', 'duration']
# First few rows:
#                                  id  \
# 0  atcosim_sm1_01_001_000000_000329
# 1  atcosim_sm1_01_002_000000_000466
# 2  atcosim_sm1_01_003_000000_000422
# 3  atcosim_sm1_01_004_000000_000264
# 4  atcosim_sm1_01_005_000000_000391
#
#                                                audio  \
# 0  {'bytes': b'RIFF\x169\x03\x00WAVEfmt \x10\x00\...
# 1  {'bytes': b'RIFF$\x8d\x04\x00WAVEfmt \x10\x00\...
# 2  {'bytes': b'RIFF\x96!\x04\x00WAVEfmt \x10\x00\...
# 3  {'bytes': b'RIFF$\x94\x02\x00WAVEfmt \x10\x00\...
# 4  {'bytes': b'RIFF\xa4\xd1\x03\x00WAVEfmt \x10\x...
#
#                                                 text  segment_start_time  \
# 0       psa eight one zero turn right to trasadingen                 0.0
# ...

# %%
# !pip install transformers torch soundfile
# Out:
# Defaulting to user installation because normal site-packages is not writeable
#   WARNING: The scripts convert-caffe2-to-onnx.exe, convert-onnx-to-caffe2.exe and torchrun.exe are installed in 'C:\Users\Mayur gowda\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
#                                               0.0/199.4 MB ? eta -:--:--
#                                               0.1/199.4 MB 2.9 MB/s eta 0:01:10
#                                               0.4/199.4 MB 5.3 MB/s eta 0:00:38
#                                               1.1/199.4 MB 8.4 MB/s eta 0:00:24
#                                              1.8/199.4 MB 10.3 MB/s eta 0:00:20
#                                              2.6/199.4 MB 11.7 MB/s eta 0:00:17
#                                              3.3/199.4 MB 12.4 MB/s eta 0:00:16
# ...

# %%
# !conda activate your_environment
# !pip install https://github.com/kpu/kenlm/archive/master.zip
# Out:
# EnvironmentNameNotFound: Could not find conda environment: your_environment
# You can list all discoverable environments with `conda info --envs`.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      - 0 bytes ? 0:00:00
#      - 35.8 kB ? 0:00:00
#      \ 182.1 kB 2.8 MB/s 0:00:00
#      \ 270.3 kB 2.8 MB/s 0:00:00
#      \ 455.7 kB 2.9 MB/s 0:00:00
#      | 553.6 kB 2.9 MB/s 0:00:00
#      | 553.6 kB 2.9 MB/s 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Failed to build kenlm
#   error: subprocess-exited-with-error
#
#   × Building wheel for kenlm (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [87 lines of output]
# ...

# %%
import pandas as pd
import io
import soundfile as sf  # For reading audio from byte streams

# List of Parquet training files
train_files = [
     r'C:\Users\Mayur gowda\OneDrive\workspace\atc clone\atcosim_corpus\data\train-00000-of-00004-c1d7fb31dcbf644a.parquet',
    r'C:\Users\Mayur gowda\OneDrive\workspace\atc clone\atcosim_corpus\data\train-00001-of-00004-f165730df6bf7253.parquet',
    r'C:\Users\Mayur gowda\OneDrive\workspace\atc clone\atcosim_corpus\data\train-00002-of-00004-67e682f17e32b703.parquet',
    r'C:\Users\Mayur gowda\OneDrive\workspace\atc clone\atcosim_corpus\data\train-00003-of-00004-b0b05d4b243c95c6.parquet'
]

# Loop through each Parquet file, load, and process the audio data
for parquet_file in train_files:
    # Load the Parquet file into a DataFrame
    df = pd.read_parquet(parquet_file)

    print(f"Processing file: {parquet_file}")

    # Extract the 'audio' column (assuming it's in bytes format as shown in your data)
    for index, row in df.iterrows():
        audio_bytes = row['audio']['bytes']

        # Convert byte data to an audio stream
        audio_stream = io.BytesIO(audio_bytes)

        # Read the audio data using soundfile
        waveform, sample_rate = sf.read(audio_stream)

        # Print basic info for each audio sample
        print(f"Sample rate: {sample_rate}, Waveform shape: {waveform.shape}")

        # Process 'waveform' as needed (e.g., pass it to Wav2Vec2 for further processing)
        # You can add the preprocessing for Wav2Vec2 here if needed
# Out:
# Processing file: C:\Users\Mayur gowda\OneDrive\workspace\atc clone\atcosim_corpus\data\train-00000-of-00004-c1d7fb31dcbf644a.parquet
# Sample rate: 32000, Waveform shape: (105593,)
# Sample rate: 32000, Waveform shape: (149120,)
# Sample rate: 32000, Waveform shape: (135353,)
# Sample rate: 32000, Waveform shape: (84480,)
# Sample rate: 32000, Waveform shape: (125120,)
# Sample rate: 32000, Waveform shape: (117760,)
# Sample rate: 32000, Waveform shape: (137600,)
# Sample rate: 32000, Waveform shape: (81280,)
# Sample rate: 32000, Waveform shape: (103252,)
# Sample rate: 32000, Waveform shape: (87360,)
# Sample rate: 32000, Waveform shape: (184882,)
# Sample rate: 32000, Waveform shape: (230720,)
# Sample rate: 32000, Waveform shape: (120960,)
# Sample rate: 32000, Waveform shape: (139174,)
# Sample rate: 32000, Waveform shape: (155520,)
# Sample rate: 32000, Waveform shape: (172480,)
# Sample rate: 32000, Waveform shape: (81505,)
# Sample rate: 32000, Waveform shape: (76085,)
# ...
